# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Dell\Documents\AI_EDA\AI_Impact_Student_Life_2026.csv")

# %%
df_dict={
    'Low' :'Low',
    'Medium' :'Medium',
    'High' :'High'
}
df_dict
# Out:
# {'Low': 'Low', 'Medium': 'Medium', 'High': 'High'}

# %%
df_plot = df['AI_Ethics_Concern'].value_counts()

for i,(num,val) in enumerate(df_dict.items()):
     plt.pie(df_plot,labels=df_plot.index,autopct='%1.1f%%',startangle=90,colors=sns.color_palette("Set3"))
     plt.title('AI Ethics Chart Range')

# %%
df
# Out:
#      Student_ID  Age                 Major Primary_AI_Tool  \
# 0      STU-6019   23  Software Engineering      Gemini Pro
# 1      STU-6962   22        Modern History  GitHub Copilot
# 2      STU-2338   18          Data Science      Perplexity
# 3      STU-1380   19               Biology      Claude 3.5
# 4      STU-1837   19               Biology      ChatGPT-4o
# ...         ...  ...                   ...             ...
# 1495   STU-2711   21        Modern History  GitHub Copilot
# 1496   STU-4888   21               Biology  GitHub Copilot
# 1497   STU-0180   23  Software Engineering  GitHub Copilot
# 1498   STU-4392   23             Fine Arts      Perplexity
# 1499   STU-4702   23          Data Science      Gemini Pro
#
#       Task_Frequency_Daily    Main_Usage_Case  GPA_Baseline  GPA_Post_AI  \
# 0                        1     Code Debugging          2.62         2.62
# 1                        3     Essay Drafting          3.99         4.00
# ...

# %%
top_ai = df.groupby(['Primary_AI_Tool','AI_Ethics_Concern']).size()

# %%
top_ai
# Out:
# Primary_AI_Tool  AI_Ethics_Concern
# ChatGPT-4o       High                  98
#                  Low                   96
#                  Medium                94
# Claude 3.5       High                  88
#                  Low                  110
#                  Medium                99
# Gemini Pro       High                 100
#                  Low                  108
#                  Medium                94
# GitHub Copilot   High                 104
#                  Low                  110
#                  Medium                97
# Perplexity       High                 106
#                  Low                   99
#                  Medium                97
# dtype: int64

# %%
top_ai
# Out:
#    Primary_AI_Tool AI_Ethics_Concern  count      perc
# 0       ChatGPT-4o              High     98  6.533333
# 1       ChatGPT-4o               Low     96  6.400000
# 2       ChatGPT-4o            Medium     94  6.266667
# 3       Claude 3.5              High     88  5.866667
# 4       Claude 3.5               Low    110  7.333333
# 5       Claude 3.5            Medium     99  6.600000
# 6       Gemini Pro              High    100  6.666667
# 7       Gemini Pro               Low    108  7.200000
# 8       Gemini Pro            Medium     94  6.266667
# 9   GitHub Copilot              High    104  6.933333
# 10  GitHub Copilot               Low    110  7.333333
# 11  GitHub Copilot            Medium     97  6.466667
# 12      Perplexity              High    106  7.066667
# 13      Perplexity               Low     99  6.600000
# 14      Perplexity            Medium     97  6.466667

# %%
pivot_top = pivot_top.apply(lambda row:row/sum(row),axis=1)*100

# %%
plt.figure(figsize=(10,4))
ax = pivot_top.plot(kind='bar',stacked=True)
plt.legend(title="Concern", bbox_to_anchor=(1,1))
plt.title('Ethic Concerns for different AIs')
plt.xlabel('')

for container in ax.containers:
    ax.bar_label(container,fmt='%1.1f%%',label_type='center')

# %%
df
# Out:
#      Student_ID  Age                 Major Primary_AI_Tool  \
# 0      STU-6019   23  Software Engineering      Gemini Pro
# 1      STU-6962   22        Modern History  GitHub Copilot
# 2      STU-2338   18          Data Science      Perplexity
# 3      STU-1380   19               Biology      Claude 3.5
# 4      STU-1837   19               Biology      ChatGPT-4o
# ...         ...  ...                   ...             ...
# 1495   STU-2711   21        Modern History  GitHub Copilot
# 1496   STU-4888   21               Biology  GitHub Copilot
# 1497   STU-0180   23  Software Engineering  GitHub Copilot
# 1498   STU-4392   23             Fine Arts      Perplexity
# 1499   STU-4702   23          Data Science      Gemini Pro
#
#       Task_Frequency_Daily    Main_Usage_Case  GPA_Baseline  GPA_Post_AI  \
# 0                        1     Code Debugging          2.62         2.62
# 1                        3     Essay Drafting          3.99         4.00
# ...
