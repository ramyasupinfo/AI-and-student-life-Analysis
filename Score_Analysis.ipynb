# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Dell\Documents\AI_EDA\AI_Impact_Student_Life_2026.csv")

# %%
fig,ax = plt.subplots(1,2)
df_before =df['GPA_Baseline'].plot(kind='hist',bins=20,edgecolor='black',ax=ax[0])
ax[0].axvline(df['GPA_Baseline'].median(),color='y',linestyle='--',label='Median')
ax[0].legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 fig,ax = plt.subplots(1,2)
# ----> 2 ax[i]=plt.gca()
#       3 df_before =df['GPA_Baseline'].plot(kind='hist',bins=20,edgecolor='black',ax=ax[0])
#       4 ax[0].axvline(df['GPA_Baseline'].median(),color='y',linestyle='--',label='Median')
#       5 ax[0].legend()
#
# NameError: name 'i' is not defined
